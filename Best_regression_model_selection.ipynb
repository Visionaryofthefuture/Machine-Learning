# %% [markdown]
# <a href="https://colab.research.google.com/github/Visionaryofthefuture/Machine-Learning/blob/main/Best_regression_model_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
df = pd.DataFrame(pd.read_csv("/content/Data.csv"))

# %%
df
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[: , -1].values

# %%
plt.figure(figsize = (10,6))
plt.scatter(X[:,3], Y)

# %% [markdown]
# Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
regressor.predict(X_test)
# Out:
# array([467.13588588, 458.24624515, 465.14796411, ..., 466.51787626,
#        436.95255967, 480.27989407])

# %%
Y_test
# Out:
# array([469.57, 448.79, 468.6 , ..., 472.41, 435.04, 478.61])

# %%
plt.figure(figsize = (10,6))
plt.scatter(X[:,1], Y, color = "red")
plt.plot(X[:,1], regressor.predict(X), color = "blue")

# %%
r2_score(Y, regressor.predict(X))
# Out:
# 0.9286808409649633

# %% [markdown]
# Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg = DecisionTreeRegressor(random_state = 0)
tree_reg.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
Y_train
# Out:
# array([463.65, 461.78, 455.29, ..., 432.59, 470.22, 436.67])

# %%
tree_reg.predict(X_train)
# Out:
# array([463.65, 461.78, 455.29, ..., 432.59, 470.22, 436.67])

# %%
plt.figure(figsize = (10,6))
plt.scatter(X[:,2], Y, color = "red")
plt.plot(X[:, 2], regressor.predict(X), color = "blue")

# %%
r2_score(Y, tree_reg.predict(X))
# Out:
# 0.9852477575991376

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest = RandomForestRegressor(random_state = 0)

# %%
random_forest.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
random_forest.predict(X_train)
# Out:
# array([464.1067, 461.234 , 455.9611, ..., 434.296 , 470.791 , 437.738 ])

# %%
Y_train
# Out:
# array([463.65, 461.78, 455.29, ..., 432.59, 470.22, 436.67])

# %%
r2_score(Y, random_forest.predict(X))
# Out:
# 0.9877338564979024

# %% [markdown]
# Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree = 2)

# %%
X_poly = poly_reg.fit_transform(X_train)
regressor.fit(X_poly , Y_train)
# Out:
# LinearRegression()

# %%
k =regressor.predict(poly_reg.fit_transform(X_test))

# %%
Y_test
# Out:
# array([469.57, 448.79, 468.6 , ..., 472.41, 435.04, 478.61])

# %%
r2_score(Y_test, k)
# Out:
# 0.9316604067029524
